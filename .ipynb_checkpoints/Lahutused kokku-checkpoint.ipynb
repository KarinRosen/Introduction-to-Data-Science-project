# %%
import pandas as pd

# %%
kuni2017 = pd.read_csv('RV331_lahutused_kuni2017.csv')
alates2017 = pd.read_csv('RV331U_lahutused_alates2017.csv')

# %%
lahutused = pd.concat([kuni2017, alates2017], ignore_index=True)

# %%
lahutused
# Out:
#     Aasta    Sugu  Alla 1 aasta  1 aasta  2 aastat  3 aastat  4 aastat  \
# 0    1994   Mehed            28       70       135       129       173
# 1    1994  Naised            27       75       141       139       176
# 2    1995   Mehed            47      119       148       200       266
# 3    1995  Naised            48      117       159       195       261
# 4    1996   Mehed            37       81       120       154       200
# 5    1996  Naised            37       79       124       158       199
# 6    1997   Mehed            38       89       124       152       138
# 7    1997  Naised            33       86       121       163       146
# 8    1998   Mehed            37       70        97       108       130
# 9    1998  Naised            38       72        94       119       130
# 10   1999   Mehed            36       83       102       105       114
# 11   1999  Naised            31       77       101       110       113
# ...

# %%
lahutused.to_csv('lahutused.csv')
